# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from Functions import cleanFunctions as cf

# %%
# Grabbing per game data for players in the 90s
year = np.array([1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000])
url1 = "https://www.basketball-reference.com/leagues/NBA_{}_per_game.html"
url2 = "https://www.basketball-reference.com/leagues/NBA_{}_per_minute.html"
url3 = "https://www.basketball-reference.com/leagues/NBA_{}_per_poss.html"
url4 = "https://www.basketball-reference.com/leagues/NBA_{}_advanced.html"
urls = np.array([url1, url2, url3, url4])
stats_year = pd.DataFrame()
stats = pd.DataFrame()
for y in year:
    for u in urls:
        # URL page we will scraping (see image above)
        url = u.format(y)

        # this is the HTML from the given URL
        html = urlopen(url)
        soup = BeautifulSoup(html)

        # use findALL() to get the column headers
        soup.findAll('tr', limit=2)
        # use getText()to extract the text we need into a list
        headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
        # exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
        headers = headers[1:]
        headers

        # avoid the first header row
        rows = soup.findAll('tr')[1:]
        player_stats = [[td.getText() for td in rows[i].findAll('td')]
                    for i in range(len(rows))]


        stats_new = pd.DataFrame(player_stats, columns = headers)
        [p, s] = stats_new.shape

        stats_year = pd.concat([stats_year, stats_new], axis=1, sort=False, ignore_index=True)
    
    stats_year.insert (4, "Year", (y*np.ones((p, 1))).astype(int))
    stats = stats.append(stats_year, ignore_index=True)
    stats_year = pd.DataFrame()

stats.head(10)
# Out:
#                     0   1   2    3  Year   4   5     6    7     8  ... 106  \
# 0      Alaa Abdelnaby  PF  22  POR  1991  43   0   6.7  1.3   2.7  ...
# 1  Mahmoud Abdul-Rauf  PG  21  DEN  1991  67  19  22.5  6.2  15.1  ...
# 2          Mark Acres   C  28  ORL  1991  68   0  19.3  1.6   3.1  ...
# 3       Michael Adams  PG  28  DEN  1991  66  66  35.5  8.5  21.5  ...
# 4        Mark Aguirre  SF  31  DET  1991  78  13  25.7  5.4  11.7  ...
# 5         Danny Ainge  SG  31  POR  1991  80   0  21.4  4.2   8.9  ...
# 6         Mark Alarie  PF  27  WSB  1991  42   1  14.0  2.4   5.4  ...
# 7        Steve Alford  PG  26  DAL  1991  34   0   6.9  1.7   3.4  ...
# 8       Greg Anderson  PF  26  TOT  1991  68   2  13.6  1.7   4.0  ...
# 9       Greg Anderson  PF  26  MIL  1991  26   0   9.5  1.0   2.8  ...
#
#     107   108   109     110 111   112   113   114   115
# 0   0.0   0.5   0.5    .079      -3.4  -1.2  -4.6  -0.2
# 1  -0.7  -0.3  -1.0  -0.031      -2.0  -3.0  -5.0  -1.1
# 2   1.4   1.1   2.5    .090      -2.8  -0.2  -3.0  -0.3
# 3   5.8   0.4   6.3    .128       6.0  -0.7   5.3   4.3
# 4   2.8   2.7   5.5    .132       1.2   0.2   1.4   1.7
# 5   4.1   2.1   6.2    .175       2.8   0.9   3.7   2.5
# 6   0.1   0.6   0.6    .050      -3.0  -0.9  -3.8  -0.3
# 7   0.5   0.1   0.6    .121       3.5  -1.4   2.1   0.2
# 8  -1.2   0.9  -0.3  -0.017      -6.8  -0.8  -7.5  -1.3
# 9  -0.5   0.4  -0.1  -0.027      -5.8  -2.1  -7.9  -0.4
#
# [10 rows x 117 columns]

# %%
#get stats on outlier and missing value incidence within the dataset
rows_missing, columns_missing, count = cf.clean(stats)

#indicates percent of dataset that is missing
percent_missing = count/(stats.shape[0] * stats.shape[1])

'''
#fill in missing values with median values
stats_medians = cf.medianImputation(df2)
'''
# Out:
# '\n#fill in missing values with median values\nstats_medians = cf.medianImputation(df2)\n'

# %%
stats.shape
# Out:
# (5153, 117)
